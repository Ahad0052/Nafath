# %%
b = int(input("enter b"))
r = int(input())
n = int(input())

n = b *(1+(r/100))**n
print(n)
# Out:
# enter b 3
#  8
#  0
# 3.0

# %%
a = 1500
bisa= (a%1000)
rial= (a//1000)
print("i have ",rial," rial and ", bisa, " bisa")

b=10500
bisa1= (b%1000)
rial1= (b//1000)
print("i have ",rial1," rial and ", bisa1, " bisa")
# Out:
# i have  1  rial and  500  bisa
# i have  10  rial and  500  bisa

# %% [markdown]
# void return value in oop

# %%
abs(-678)
# Out:
# 678

# %% [markdown]
# task:
# what is the diff btn methods and functions

# %%
from math import *
y = sqrt(5)
print(y)
print(int(y))
# Out:
# 2.23606797749979
# 2

# %%
t =10
t +=5
print(t)
# Out:
# 15

# %%
fn = "Ahad"
ln = "Aljabri"
n = fn + " " + ln
print(n)
print(fn, " ", ln)
# Out:
# Ahad Aljabri
# Ahad   Aljabri

# %%
b = "x" *100
print(b)
# Out:
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx

# %%
name = "ahad salim"
print(len(name))
print(name[9],name[-1])
# Out:
# 10
# m m

# %%
print("\\")
# Out:
# \

# %%
n = input("name: ")
age = int(input("age: "))
# Out:
# name:  h
# age:  8

# %% [markdown]
# hw write article in linkedin about to use in print like , , or %(a)  %.2f

# %%
ppl=11111
print("price is %4d" %(ppl))
# Out:
# price is 11111

# %%
cpp=6
input1 = input()
pp = float(input1)
input2 = input()
cv = float(input2)
pv = pp * cpp
ppo = pp / pv
print("%f"  %ppo)
# Out:
#  2
#  4
# 0.166667

# %%
floor= int(input("floor number: "))
if floor>13:
    af=floor-1
elif floor == 13 :
    af=floor
    print("danger")
else :
    af = floor
print(af)
# Out:
# floor number:  13
# danger
# 13

# %%
n= int(input("enter a number: "))
a = n % 2
print("mod is ", a)
if a == 0:
    print("number is even")
else:
    print("numer is odd")
# Out:
# enter a number:  -456
# mod is  0
# number is even

# %%
n= int(input("enter the grade: "))

if n >= 85:
    print("discount")
else:
    print("nothing")
# Out:
# enter the grade:  85
# discount

# %%
from sys import exit
g = float(input("enter your grade: "))
if g > 100 or g < 0:
    exit("wrong value")


if g >=90 and g <=100 :
    print("a")
elif g>=80 and g<90:
    print("b")
elif g>=70 and g<80:
    print("c")
elif g>=60 and g<70:
    print("c")
elif g>=50 and g<60:
    print("p")
else:
    print("fail")
# Out:
# enter price:  130
# price after discount is  119.60000000000001
