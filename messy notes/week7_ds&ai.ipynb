# %% [markdown]
# select m.title ,g.name1, q.text1
# from moviec m
# inner join movie_gener mg on m.m_id = mg.movieid
# inner join gener g on mg.generid = g.gener_id
# inner join quots q on q.moid = m.m_id;
#
#
# select g.name1, m.title
# from gener g
# right join movie_gener mg on g.gener_id = mg.generid
# right join moviec m on m.m_id = mg.movieid;
#
# -- List all movies and their production company names, including movies that do not have a production company assigned.
# select p.pname , m.title
# from moviec m
# left join prod p on m.pid = p.p_id;
# -- List all actors and the movies they acted in, including actors who have not acted in any movie.
# select a.name1 , m.title
# from moviec m
# left join actor a on a.actor_id = m.actor_id;
#
# -- List all actors and the quotes they said using RIGHT JOIN, including quotes that are not linked to any actor.
# select q.text1 , a.name1
# from actor a
# right join quots q on a.actor_id = q.actid;
#
# -- Display all movies and their genres using RIGHT JOIN, including genres that currently have no movies assigned.
# select g.name1, m.title
# from gener g
# right join movie_gener mg on g.gener_id = mg.generid
# right join moviec m on m.m_id = mg.movieid;
#
# -- union
#
# select g.name1, m.title
# from gener g
# left join movie_gener mg on g.gener_id = mg.generid
# left join moviec m on m.m_id = mg.movieid
# union
# select g.name1, m.title
# from gener g
# right join movie_gener mg on g.gener_id = mg.generid
# right join moviec m on m.m_id = mg.movieid;
#
# select a.name1 , m.title
# from moviec m
# cross join actor a;
#
# -- self join on uniray relationship
# -- https://www.sqlnoir.com/blog/sql-join-types-explained
# -- https://claude.ai/public/artifacts/59011d73-da0b-48ff-875d-76e26587c63f

# %% [markdown]
# in project add :
# 1. index
# 2. views
# 3. tcl

# %% [markdown]
# Introduction to Data Scienc
# Concepts and Applications
#
# Introduction to Data Science
# Data Ethics & Future Trend
#
# Introduction to Data Science
# Exploratory Data Analysis Componenet
