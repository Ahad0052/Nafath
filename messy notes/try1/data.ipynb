# %%
import pandas as pd


data = pd.read_csv("muscat_historical_traffic_dataset.csv")
df = pd.DataFrame(data)
print(df.info(), df.describe())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 183960 entries, 0 to 183959
# Data columns (total 7 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   road_name           183960 non-null  str
#  1   speed_limit         183960 non-null  float64
#  2   timestamp           183960 non-null  str
#  3   hour                183960 non-null  int64
#  4   day_of_week         183960 non-null  int64
#  5   observed_speed_kmh  183960 non-null  float64
#  6   congestion_index    183960 non-null  float64
# dtypes: float64(3), int64(2), str(2)
# memory usage: 9.8 MB
# None          speed_limit           hour   day_of_week  observed_speed_kmh  \
# count  183960.000000  183960.000000  183960.00000       183960.000000
# mean       92.857143      13.000000       3.00411           73.411312
# std         9.583175       6.831319       1.99943           21.102727
# min        80.000000       3.000000       0.00000           24.000000
# ...

# %%
df["road_name"].unique()
# Out:
# <StringArray>
# [                         'الطريق البحري',
#                      'شارع سلطان بن أحمد',
#                              'شارع تيمور',
#                           'شارع السعيدية',
#  '['شارع السعيدية', 'شارع باب المثاعيب']']
# Length: 5, dtype: str
